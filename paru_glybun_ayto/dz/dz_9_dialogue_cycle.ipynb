# %% [markdown]
#  # ЗАДАЧА:
#     # сделать бесконечй цикл для диалога с моделью в одном чате с сохранением всего этого контекста
#     # если пользователь вводит "/exit", то выйти из цикла
#     # если вводит "/clear", то очистить историю, кроме system prompt
#     # если вводит "/system какой-то текст", то всё что после /system - будет системный промптом
#     # для задачи обязательно использовать rich console https://rich.readthedocs.io/en/latest/console.html
#     # и panel для красоты https://rich.readthedocs.io/en/latest/panel.html
#     # + форматирование через https://rich.readthedocs.io/en/latest/markdown.html

# %%
from rich.console import Console
from rich.panel import Panel
from rich.prompt import Prompt
from rich.markdown import Markdown
import openai

console = Console()
messages = [{"role": "system", "content": "Ты полезный помощник."}]

# === Подключение к OpenRouter (точно как у Фионы) ===
API_KEY = "2e3fc559-ee86-42b8-9663-b44e3266fd55"  # ← ЗАМЕНИТЕ НА РАБОЧИЙ КЛЮЧ

client = openai.OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=API_KEY
)

def print_message(role, content):
    if role == "user":
        panel = Panel(f"[blue]👤: {content}[/blue]", title="Вы", title_align="left", border_style="blue")
    else:
        md = Markdown(content)
        panel = Panel(md, title="🤖 Модель", title_align="left", border_style="green")
    console.print(panel)

console.print(Panel.fit("💬 Чат стартанул! /exit, /clear, /system", title="Диалог", border_style="yellow"))

while True:
    try:
        us_um = Prompt.ask("👤").strip()
        
        if not us_um:
            continue
            
        if us_um == "/exit":
            console.print(Panel("👋 Пока!", title="Завершение", expand=False))
            break
            
        elif us_um == "/clear":
            messages = [messages[0]]
            console.print(Panel("🧹 История очищена", expand=False))
            continue
            
        elif us_um.startswith("/system "):
            new_system_prompt = us_um[8:]
            messages[0] = {"role": "system", "content": new_system_prompt}
            console.print(Panel(f"⚙️ Новый системный промпт:\n{new_system_prompt}", expand=False))
            continue

        messages.append({"role": "user", "content": us_um})
        print_message("user", us_um)

        try:
            response = client.chat.completions.create(
                model="openai/gpt-4o-mini",
                messages=messages,
                temperature=0.7
            )
            ass_r = response.choices[0].message.content.strip()
        except openai.AuthenticationError:
            ass_r = "❌ Ошибка: Неверный API-ключ. Проверьте ключ на сайте OpenRouter."
        except Exception as e:
            ass_r = f"❌ Ошибка: {str(e)}"

        messages.append({"role": "assistant", "content": ass_r})
        print_message("assistant", ass_r)

    except KeyboardInterrupt:
        console.print(Panel("\n👋 Прервано пользователем!", title="Выход", expand=False))
        break
# Out:
# ╭───────────────── Диалог ─────────────────╮
# │ 💬 Чат стартанул! /exit, /clear, /system │
# ╰──────────────────────────────────────────╯
# 👤:
# 👤:
# ╭───────────────────────────╮
# │ ⚙️ Новый системный промпт: │
# │ hi!!                      │
# ╰───────────────────────────╯
# 👤:
# ╭───────────────────────────╮
# │ ⚙️ Новый системный промпт: │
# │ who                       │
# ╰───────────────────────────╯
# 👤:

# %%
from rich.console import Console
from rich.panel import Panel
from rich.prompt import Prompt
from rich.markdown import Markdown
import openai

console_1 = Console()
all_messages = [{"role": "system", "content": "Ты полезный помощник."}]
kluchik = "не смотрите, бе бе бе"
client_bot = openai.OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=kluchik
)

def vivod_cool(role_pol, text_pol):
    if role_pol == "user":
        panel_pol = Panel(f"[blue]👤: {text_pol}[/blue]", title="Вы", title_align="left", border_style="blue")
    else:
        md_pol = Markdown(text_pol)
        panel_pol = Panel(md_pol, title="🤖 Модель", title_align="left", border_style="green")
    console_1.print(panel_pol)

console_1.print(Panel.fit("💬 Чат стартанул! /exit, /clear, /system", title="Диалог", border_style="yellow"))

while True:
    try:
        user_vvod = Prompt.ask("👤").strip()
        
        if not user_vvod:
            continue
            
        if user_vvod == "/exit":
            console_1.print(Panel("👋 Пока!", title="Завершение", expand=False))
            break
            
        elif user_vvod == "/clear":
            all_messages = [all_messages[0]]
            console_1.print(Panel("🧹 История очищена", expand=False))
            continue
            
        elif user_vvod.startswith("/system "):
            new_sys_prompt = user_vvod[8:]
            all_messages[0] = {"role": "system", "content": new_sys_prompt}
            console_1.print(Panel(f"⚙️ Новый системный промпт:\n{new_sys_prompt}", expand=False))
            continue

        # добавляем ваше сообщение
        all_messages.append({"role": "user", "content": user_vvod})
        vivod_cool("user", user_vvod)

        try:
            otvet_bot = client_bot.chat.completions.create(
                model="openai/gpt-4o-mini",
                messages=all_messages,
                temperature=0.7
            )
            otvet_text = otvet_bot.choices[0].message.content.strip()
        except openai.AuthenticationError:
            otvet_text = "❌ Ошибка: Неверный API-ключ. Проверьте ключ на сайте OpenRouter."
        except Exception as err:
            otvet_text = f"❌ Ошибка: {str(err)}"

        # добавляем ответ бота
        all_messages.append({"role": "assistant", "content": otvet_text})
        vivod_cool("assistant", otvet_text)

    except KeyboardInterrupt:
        console_1.print(Panel("\n👋 Прервано пользователем!", title="Выход", expand=False))
        break
# Out:
# ╭───────────────── Диалог ─────────────────╮
# │ 💬 Чат стартанул! /exit, /clear, /system │
# ╰──────────────────────────────────────────╯
# 👤:
# ╭─ Вы ────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 👤: приветули                                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ 🤖 Модель ─────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Привет! Как я могу помочь тебе сегодня?                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 👤:
# ╭─ Вы ────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# ...
